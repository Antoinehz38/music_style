# %%
# Aller dans le dossier de travail Kaggle
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8

# %cd /kaggle/working

# Effacer l'ancienne version du repo
# !rm -rf music_style

# Cloner le repo (Internet doit être activé dans les Settings du notebook)
# !git clone https://github.com/Antoinehz38/music_style.git

# Se placer dans le repo
# %cd music_style

# Adapter la version Python dans pyproject.toml
from pathlib import Path
p = Path("pyproject.toml")
p.write_text(p.read_text().replace(">=3.12", ">=3.10"))

# Installer le package en editable
# !pip install -e .
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8
# /kaggle/working
# Cloning into 'music_style'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (296/296), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 296 (delta 195), reused 197 (delta 96), pack-reused 0 (from 0)
# Receiving objects: 100% (296/296), 12.95 MiB | 40.44 MiB/s, done.
# Resolving deltas: 100% (195/195), done.
# /kaggle/working/music_style
# Obtaining file:///kaggle/working/music_style
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.9 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.1 MB/s eta 0:00:00:00:0100:01
# ...

# %%
import torch, os 

print(torch.cuda.is_available())
print(os.cpu_count())
# Out:
# True
# 4

# %%
# %cd /kaggle/working/music_style

# !rm -rf data
# !mkdir -p data

# lien symbolique vers ton dataset mels128
# !ln -s /kaggle/input/mels128/mels128 data/mels128

# si tu as un autre dataset
# !ln -s /kaggle/input/fma-metadata/fma_metadata data/fma_metadata
# Out:
# /kaggle/working/music_style

# %%
# %cd /kaggle/working/music_style
# !python -m src.train --run_from "src/runs_configs/2025-12-07_00-34-06.json"
# Out:
# /kaggle/working/music_style
# nombre de cpu :  4
# 2025-12-07 23:03:46.560397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765148626.585117     676 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765148626.592763     676 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/tensorboard/compat/__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %cd /kaggle/working/music_style
# !python -m src.eval_model --run_from "src/runs_configs/2025-12-07_12-44-43.json" --no-vote
# Out:
# /kaggle/working/music_style
# config = {'model_type': 'SmallCRNN', 'dataset_type': 'MelNpyDataset', 'batch_size': 32, 'target_T': 1292, 'random_crop': True, 'epoch': 30, 'lr': 0.001, 'optim_type': 'AdamW', 'weight_decay': 0.0002, 'seed': 1234, 'use_augment': True, 'final_result': 0.628125, 'name': 'best_model_2025-12-07_12-44-43.pt', 'val_training': False, 'scheduler': True}
# No vote classic evaluation
# FINAL test accuracy: 0.625

# %%
# %cd /kaggle/working/music_style/src/weight
# %ls
# Out:
# /kaggle/working/music_style/src/weight
# baseline_model.pt                  best_model_2025-12-02_19-13-15.pt
# best_model_2025-11-24_20-56-04.pt  best_model.pt
# best_model_2025-11-24_22-16-23.pt
